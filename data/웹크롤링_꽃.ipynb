# %%
from selenium import webdriver as wd
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.action_chains import ActionChains

import time
import pandas as pd
import numpy as np

# %% [markdown]
# ## 사이트 꽃(웹크롤링) 가져오기

# %%
#브라우저 꺼짐 방지 
chrome_options = Options()
chrome_options.add_experimental_option("detach", True)

#페이지 열기
link="https://honestflower.kr/flower-wiki"

driver= wd.Chrome(options=chrome_options)
driver.get(link)

# %%
#무한 스크롤
import time

SCROLL_PAUSE_TIME = 2

# Get scroll height (마지막 시점의 창 높이 저장)
last_height = driver.execute_script("return document.body.scrollHeight")         

while True:
    # Scroll down to bottom (창 높이까지 스크롤)                                                    
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page (스크롤 후 창 로딩될 때까지 기다림)
    time.sleep(SCROLL_PAUSE_TIME)                                                
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight-50);")  
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height (스크롤이 된 후에 창 높이를 새로운 높이로 저장)
    new_height = driver.execute_script("return document.body.scrollHeight")

    if new_height == last_height: #새로운 높이가 이전 높이와 변하지 않았으면 스크롤 종료
        break

    last_height = new_height

# %%
#꽃 카드에서 모든 정보 추출

flower=[]

for i in range(1,437): #총 436개의 꽃
    flower_table={}
    try:
        #꽃 이름
        flower_table['꽃'] = driver.find_element(By.XPATH, '//*[@id="layoutContainer"]/section/div/div/section/article/div[2]/article/ul/div[{}]/li/div[1]/h3'.format(i)).text
        #꽃 이미지
        flower_table['이미지'] = driver.find_element(By.XPATH, '//*[@id="layoutContainer"]/section/div/div/section/article/div[2]/article/ul/div[{}]/li/div[1]/img'.format(i)).get_attribute('src')
        #꽃말
        flower_table['꽃말'] = driver.find_element(By.XPATH, '//*[@id="layoutContainer"]/section/div/div/section/article/div[2]/article/ul/div[{}]/li/div[2]/p'.format(i)).text
        #계절
        flower_table['계절'] = driver.find_element(By.XPATH, '//*[@id="layoutContainer"]/section/div/div/section/article/div[2]/article/ul/div[{}]/li/div[2]/div'.format(i)).text

        #카드 클릭
        #driver.find_element(By.XPATH, '//*[@id="layoutContainer"]/section/div/div/section/article/div[2]/article/ul/div[3]').click() #div class="FlowerCardLayout_listBox__TOusq"
        driver.find_element(By.XPATH, '//*[@id="layoutContainer"]/section/div/div/section/article/div[2]/article/ul/div[{}]/li'.format(i)).click() #liv class="Listitem_root_pRjpx"
        time.sleep(0.5)
        driver.find_element(By.XPATH, '//*[@id="layoutContainer"]/section/div/div/section/article/div[2]/div/div/div[1]/div[1]/article/div[1]/img').click() #img src
        #설명
        flower_table['설명']=driver.find_element(By.CSS_SELECTOR, '#layoutContainer > section > div.Layout_innerContainer__B6qVW.Layout_headerHide__azLeL > div > section > article > div.FlowerCardLayout_listContainer___c_1z > div.FlowerCardLayout_overLayout__dFIb8.FlowerCardLayout_desktopWidth__9cnsr > div > div.FlowerCardLayout_cardBox__LTtf0 > div:nth-child(2) > article > div.CardBack_info__e9jQU > p').text

        #JavaScript를 사용하여 빈 화면 클릭, 페이지의 좌표 (100, 100)를 클릭
        click_script = "document.elementFromPoint(100, 180).click();"
        driver.execute_script(click_script)

        flower.append(flower_table)

    except Exception as e:
        print("에러발생")
        continue
# Out:
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생
# 에러발생

# %%
flower_df=pd.DataFrame.from_dict(flower)
flower_df.shape
# Out:
# (241, 5)

# %%
flower_df
# Out:
#                  꽃                                                이미지  \
# 0               작약  https://file.honestflower.kr/media/images/ingr...
# 1         스프레이 델피늄  https://file.honestflower.kr/media/images/ingr...
# 2               귀리  https://file.honestflower.kr/media/images/ingr...
# 3            열매 냉이  https://file.honestflower.kr/media/images/ingr...
# 4             베로니카  https://file.honestflower.kr/media/images/ingr...
# ..             ...                                                ...
# 236          피스타시아  https://file.honestflower.kr/media/images/ingr...
# 237  피에스타 코마치 카네이션  https://file.honestflower.kr/media/images/ingr...
# 238       피에트 카네이션  https://file.honestflower.kr/media/images/ingr...
# 239        피치팡팡 장미  https://file.honestflower.kr/media/images/ingr...
# 240     핑크익스프레션 장미  https://file.honestflower.kr/media/images/ingr...
#
#                 꽃말             계절  \
# 0              수줍음              봄
# 1    당신을 행복하게 해줄게요  봄\n여름\n가을\n겨울
# 2               검소  봄\n여름\n가을\n겨울
# 3           충실, 견고      봄\n여름\n가을
# 4            충실,견고  봄\n여름\n가을\n겨울
# ..             ...            ...
# 236             고요          봄\n여름
# 237             존경  봄\n여름\n가을\n겨울
# 238             존경  봄\n여름\n가을\n겨울
# 239         행복한 사랑  봄\n여름\n가을\n겨울
# 240         사랑의 맹세  봄\n여름\n가을\n겨울
#
#                                                     설명
# 0    봉오리일 땐 작고 동그란 모습을 가진 작약은 개화하면 풍성한 겹꽃잎으로 화려한 모습...
# 1    꽃잎의 모양이 돌고래를 닮은 투명한 꽃잎이 화사하고, 여성스러운 느낌을 줍니다. 단...
# 2    춤추는 들녘의 우아함을 담은 귀리는 줄기에 맺힌 열매가 만들어내는 형태가 아름다워요...
# 3    내추럴한 느낌을 주는 이 꽃은 들판에서 바람에 흔들리는 들꽃을 떠올리게 하는 소박한...
# 4    봄-여름 들판에서 바람에 흔들리는 모습이 연상되는 대표적인 풀꽃으로 범의 꼬리를 닮...
# ..                                                 ...
# 236  지중해 유럽의 건조하고 바위가 많은 토양에서 자라는 매스틱 나무는 옻나무과의 관목인...
# 237  다양한 컬러와 품종이 유통되기때문에 이제는 어버이날 이외에도 여러가지 플라워 믹스 ...
# 238  다양한 컬러와 품종이 유통되기때문에 이제는 어버이날 이외에도 여러가지 플라워 믹스 ...
# 239  오렌지와 핑크가 오묘하게 섞인 색감의 스프레이 장미로 처음에는 짙은 코랄색이 눈길을...
# 240  일반 장미 꽃잎의 배열과는 다르게 독특한 형태로 피어나는 화형을 가진 정원 장미 (...
#
# [241 rows x 5 columns]

# %%
flower_df.to_csv("C:/Users/pc/Desktop/민지/동아리/프로젝트(13기)/사이트 꽃2.csv")
